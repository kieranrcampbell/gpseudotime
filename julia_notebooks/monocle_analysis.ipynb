# %%
using Gadfly
using HDF5
using DataFrames

include("../bgplvm.jl"); # load in inference & plotting methods;

# %%
X = h5read("../data/embeddings.h5", "monocle/embedding")
t_gt = h5read("../data/embeddings.h5", "monocle/pseudotime");

# %%
plot(x = X[:,1], y = X[:,2], colour = t_gt)
# Out:
# Plot(...)

# %%
# remove cells less than 0 on x
to_keep = X[:,1] .> 0
X = X[to_keep,:]
t_gt = t_gt[to_keep]

x = X[:,1] ; y = X[:,2]
xs = (x - mean(x)) / sqrt(var(x))
ys = (y - mean(y)) / sqrt(var(y))
plot(x = xs, y = ys, color = t_gt)
# Out:
# Plot(...)

# %%
#plot(x = X[:,1], y = X[:,2], colour = t_gt)
X_old = X
X = [xs ys];
size(X)
# Out:
# (155,2)

# %% [markdown]
# ### Using large kernel parameters

# %%
srand(123)

n = size(X)[1]

n_iter = 300000
burn = n_iter / 2

thin = 500

# pseudotime parameters
eps = 1e-6
t =  rand(Uniform(.5 - eps, .5 + eps), n) # t_gt #  
tvar = 6.5e-3

# kernel parameters
lambda = [.5, .5]
sigma = [.5, .5]

lvar = [1e-2, 1e-2] * .9
svar = [1e-2, 1e-2] * .8

r = 1e-3 # repulsion parameter

return_burn = true # should the burn period be returned in the traces?
cell_swap_probability = 0 # randomly swap two cells at each stage?

mh1 = B_GPLVM_MH(X, n_iter, burn, thin, t, tvar, lambda, lvar, 
                sigma, svar, r, return_burn, cell_swap_probability)
# Out:
# Dict{Any,Any} with 9 entries:
#   "burn_acceptance_rate" => 0.4417566666666667
#   "lambda_chain"         => [0.5 0.5…
#   "sigma_chain"          => [0.5 0.5…
#   "prior_chain"          => [-321.03415261182835,-27.78557851834558,-23.1207754…
#   "r"                    => 0.001
#   "params"               => {"n_iter"=>300000,"burn_thin"=>300,"burn"=>150000.0…
#   "loglik_chain"         => [-491.1729252189181,-442.20251161767237,-443.489386…
#   "tchain"               => [0.5000005368953504 0.5000008810300015 0.5000003479…
#   "acceptance_rate"      => 0.4417566666666667

# %%
plot_pseudotime_trace(mh1)
# Out:
# Plot(...)

# %%
plot_kernel_parameter(mh1, "lambda")
# Out:
# Plot(...)

# %%
plot_kernel_parameter(mh1, "sigma")
# Out:
# Plot(...)

# %%
bt = mh1["params"]["burn_thin"]
Gadfly.plot(x = vec(t_gt), y = vec(mean(mh1["tchain"][bt:end,:], 1)))
# Out:
# Plot(...)

# %%
tp = linspace(0, 1, 50)
plot_posterior_mean(mh1, tp, X)
# Out:
# Plot(...)

# %%
plot_likelihood(mh1)
# Out:
# Plot(...)

# %%
plot_prior(mh1)
# Out:
# Plot(...)

# %%
#plot(x = t_gt, y = mean(mh1["tchain"][burn:end,:], 1))

# %% [markdown]
# ### Using small kernel parameters

# %%
mh2 = B_GPLVM_MH(X, n_iter, burn, thin, t, tvar, [lambda / 100, sigma / 100], [lvar, svar], 1, true)
# Out:
# Dict{Any,Any} with 8 entries:
#   "burn_acceptance_rate" => 0.38
#   "prior_chain"          => [-221537.48718500027,-153475.4974322899,-146818.944…
#   "theta_chain"          => [0.01 0.01…
#   "r"                    => 1
#   "loglik_chain"         => [-15369.674524638176,-15369.658231257317,-15369.655…
#   "tchain"               => [0.49991732698572766 0.499965025757255 0.4999813450…
#   "acceptance_rate"      => 0.38
#   "params"               => {"n_iter"=>2000,"burn_thin"=>100,"burn"=>1000.0,"th…

# %%
plot_pseudotime_trace(mh2)
# Out:
# Plot(...)

# %%
plot_kernel_parameter(mh2, "lambda")
# Out:
# Plot(...)

# %%
plot_kernel_parameter(mh2, "sigma")
# Out:
# Plot(...)

# %%
Gadfly.plot(x = t_gt, y = mean(mh2["tchain"][mh2["burn_thin"]:end,:], 1))
# Out:
# key not found: "burn_thin"
# while loading In[57], in expression starting on line 1
#
#  in getindex at dict.jl:617

# %%
plot_posterior_mean(mh2, burn, tp, X)
# Out:
# Plot(...)

# %%
function B_GPLVM_MH(X, n_iter, burn, thin, 
    t, tvar, theta, theta_var, r = 1, return_burn = false)
    
    chain_size = int(floor(n_iter / thin)) + 1 # size of the thinned chain
    burn_thin = int(floor(burn / thin)) # size of the burn region of the thinned chain
    
    n, ndim = size(X)
    @assert ndim == 2
    
    lambda, sigma = theta
    lvar, svar = theta_var
    
    ## chains
    tchain = zeros((chain_size, n))
    tchain[1,:] = t

    theta_chain = zeros((n_iter + 1), 2)
    theta_chain[1,:] = [lambda, sigma]
    
    accepted = zeros(n_iter)

    loglik_chain = zeros(chain_size)
    prior_chain = zeros(chain_size)
    
    loglik_chain[1] = log_likelihood(X, t, [lambda, sigma])
    prior_chain[1] = corp_prior(t)
    
    ## MH
    for i in 1:n_iter
        # proposals
        t_prop = propose_t(t, tvar)
        lambda_prop = propose(lambda, lvar)
        sigma_prop = propose(sigma, svar)

        # calculate acceptance ratio
        alpha = acceptance_ratio(X, t_prop, t, 
                                [lambda_prop, sigma_prop], 
                                [lambda, sigma], r, 1)

        # accept - reject
        if alpha > log(rand())
            # accept
            accepted[i] = 1
            t = t_prop
            (lambda, sigma) = [lambda_prop, sigma_prop]
        end
        
    
        if i % thin == 0
            # update traces
            j = int(i / thin) + 1
            tchain[j,:] = t
            theta_chain[j,:] = [lambda, sigma]
            loglik_chain[j] = log_likelihood(X, t, [lambda, sigma])
            prior_chain[j] = corp_prior(t)
        end
    end
    
    burnt = burn_thin
    if return_burn
        burnt = 1
    end
    
    rdict = {"tchain" => tchain[burnt:end,:],
        "theta_chain" => theta_chain[burnt:end,:],
        "acceptance_rate" => (sum(accepted) / length(accepted)),
        "burn_acceptance_rate" => (sum(accepted[burnt:end]) / length(accepted[burnt:end])),
        "r" => r,
        "loglik_chain" => loglik_chain,
        "prior_chain" => prior_chain,
        "params" => {"n_iter" => n_iter,
                    "burn" => burn,
                    "thin" => thin,
                    "burn_thin" => burn_thin
            }
        }
    return rdict
end
# Out:
# B_GPLVM_MH (generic function with 4 methods)

# %%
n_iter = 100
burn = 50
thin = 2
mh3 = B_GPLVM_MH(X, n_iter, burn, thin, t, tvar, [lambda / 100, sigma / 100], [lvar, svar], 1, true)
# Out:
# Dict{Any,Any} with 8 entries:
#   "burn_acceptance_rate" => 0.21
#   "prior_chain"          => [-19625.831457669614,-19586.99371643533,-19585.56917…
#   "theta_chain"          => [0.0001 0.0001…
#   "r"                    => 1
#   "loglik_chain"         => [916.203436000821,902.598992915586,901.3817539588981…
#   "tchain"               => [0.07326988646322778 0.11054894736125531 0.167844886…
#   "acceptance_rate"      => 0.21
#   "params"               => {"n_iter"=>100,"burn_thin"=>25,"burn"=>50,"thin"=>2}
