# %%
using Gadfly
using HDF5
using DataFrames

include("../bgplvm.jl"); # load in inference & plotting methods;

# %%
X = h5read("../data/embeddings.h5", "monocle/embedding")
t_gt = h5read("../data/embeddings.h5", "monocle/pseudotime");

# %%
plot(x = X[:,1], y = X[:,2], colour = t_gt)
# Out:
# Plot(...)

# %%
# remove cells less than 0 on x
to_keep = X[:,1] .> 0
X = X[to_keep,:]
t_gt = t_gt[to_keep]

x = X[:,1] ; y = X[:,2]
xs = (x - mean(x)) / sqrt(var(x))
ys = (y - mean(y)) / sqrt(var(y))
plot(x = xs, y = ys, color = t_gt)
# Out:
# Plot(...)

# %%
#plot(x = X[:,1], y = X[:,2], colour = t_gt)
X_old = X
X = [xs ys];
size(X)
# Out:
# (155,2)

# %% [markdown]
# ### Inference

# %%
srand(123)

n = size(X)[1]

n_iter = 100000
burn = n_iter / 2

thin = int(n_iter / 1000)

# pseudotime parameters
eps = 1e-6
t =  rand(Uniform(.5 - eps, .5 + eps), n) # t_gt #  
tvar = 6.5e-3

# kernel parameters
lambda_init = [4, 4]
sigma_init = [.1, .1]

lvar = [1, 1] * 9e-3
svar = [1, 1] * 1e-4

r = 1e-3 # repulsion parameter

return_burn = true # should the burn period be returned in the traces?
cell_swap_probability = 0 # randomly swap two cells at each stage?

gamma = 100.0
delta = 10e-3

mh1 = B_GPLVM_MH(X, n_iter, burn, thin, t, tvar, lambda_init, lvar, 
sigma_init, svar, r, return_burn, cell_swap_probability, gamma, delta)
# Out:
# Dict{Any,Any} with 9 entries:
#   "burn_acceptance_rate" => 0.3534
#   "lambda_chain"         => [4.0 4.0…
#   "sigma_chain"          => [0.1 0.1…
#   "prior_chain"          => [-321.03415261182835,-50.17662433921207,-44.75845819…
#   "r"                    => 0.001
#   "params"               => {"n_iter"=>100000,"burn_thin"=>500,"burn"=>50000.0,"…
#   "loglik_chain"         => [-1475.3169110416352,-1243.0010930563599,-1025.58074…
#   "tchain"               => [0.5000005368953504 0.5000008810300015 0.50000034791…
#   "acceptance_rate"      => 0.3534

# %%
plot_pseudotime_trace(mh1)
# Out:
# Plot(...)

# %%
plot_kernel_parameter(mh1, "lambda")
# Out:
# Plot(...)

# %%
plot_kernel_parameter(mh1, "sigma")
# Out:
# Plot(...)

# %%
bt = mh1["params"]["burn_thin"]
Gadfly.plot(x = vec(t_gt), y = vec(mean(mh1["tchain"][bt:end,:], 1)))
# Out:
# Plot(...)

# %%
tp = linspace(0, 1, 50)
plot_posterior_mean(mh1, tp, X)
# Out:
# Plot(...)

# %%
plot_likelihood(mh1)
# Out:
# Plot(...)

# %%
plot_prior(mh1)
# Out:
# Plot(...)

# %% [markdown]
# ## Measures of reordering

# %%
kt = kendall_tau(mh1)
plot(x = 1:length(kt), y = kt)
# Out:
# Plot(...)
